# %%
#expand cell width to 100%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#import pandas 
import pandas as pd
#import numpy
import numpy as np

# %%
#set the address of the dataframe containing the pre-processed dataset
dataFramePickleAddress="C:/ML4Sci/Ml4Sci_GRS_abundance_estimation/Dataset/GRSFiveDegreeSectionPreProcessedDataset.pkl"
#dataFramePickleAddress="D:/Non-academic/GSOC23/Ml4Sci_GRS_abundance_estimation/Dataset/GRSFiveDegreeSectionPreProcessedDataset.pkl"

# %%
#read the dataframe
dataframe=pd.read_pickle(dataFramePickleAddress)

# %%
#print the dataframe
dataframe
# Out:
#       Max Lat per section  Min Lat per section  Max Lon per section  \
# 0                   -87.5                -90.0                180.0
# 1                   -82.5                -87.5               -135.0
# 2                   -82.5                -87.5                -90.0
# 3                   -82.5                -87.5                -45.0
# 4                   -82.5                -87.5                  0.0
# ...                   ...                  ...                  ...
# 1785                 87.5                 82.5                 45.0
# 1786                 87.5                 82.5                 90.0
# 1787                 87.5                 82.5                135.0
# 1788                 87.5                 82.5                180.0
# 1789                 90.0                 87.5                180.0
#
#       Min Lon per section  No. of spectra per section  \
# 0                  -180.0                        7002
# 1                  -180.0                        1599
# 2                  -135.0                        1940
# 3                   -90.0                        1818
# 4                   -45.0                        1855
# ...                   ...                         ...
# 1785                  0.0                        1748
# 1786                 45.0                        2035
# 1787                 90.0                        1903
# 1788                135.0                        1902
# 1789               -180.0                        7294
#
#       Total active time per section  \
# 0                     215153.707937
# 1                      49113.391313
# 2                      59600.854365
# 3                      55864.552890
# 4                      57007.157885
# ...                             ...
# 1785                   53653.126808
# 1786                   62483.348769
# 1787                   58474.988092
# 1788                   58399.244640
# 1789                  223993.416783
#
#                                          Summed Spectra  \
# 0     [270112.3731329723, 44221.71628033137, 45327.9...
# 1     [101728.76450092324, 11353.802617173642, 10565...
# 2     [69004.10988058499, 13041.311258502305, 12455....
# 3     [51455.21453525051, 11348.088811988011, 11487....
# 4     [51138.233213284286, 10203.879826977849, 12005...
# ...                                                 ...
# 1785  [172204.68795185376, 12837.986652251333, 11392...
# 1786  [69631.4865040512, 13027.290796013549, 12597.1...
# 1787  [58870.11519813659, 11691.651373354718, 11794....
# 1788  [69077.49428235987, 10543.676356979646, 11999....
# 1789  [342422.3644296753, 45978.50919445278, 45791.6...
#
#                                      Normalized Spectra  \
# 0     [75.32634479500912, 12.332127585726989, 12.640...
# 1     [124.27824075904886, 13.87051756806718, 12.906...
# 2     [69.4662289143658, 13.12864863838364, 12.53878...
# 3     [55.264254565457236, 12.188146033430378, 12.33...
# 4     [53.82296024948041, 10.739577490433051, 12.635...
# ...                                                 ...
# 1785  [192.57556626933405, 14.356650673799725, 12.73...
# 1786  [66.8640409410214, 12.509531949810704, 12.0964...
# 1787  [60.40543191435932, 11.996566485773727, 12.102...
# 1788  [70.97094632772614, 10.832684314943478, 12.328...
# 1789  [91.72297186611817, 12.316034066037092, 12.265...
#
#                                  Log Normalized Spectra  Aluminum  ...  \
# 0     [1.8769468938381042, 1.0910380092016139, 1.101...    15.151  ...
# 1     [2.0943950968999223, 1.1420926667518603, 1.110...    13.394  ...
# 2     [1.8417737231418783, 1.118220025472807, 1.0982...    13.634  ...
# 3     [1.742444316396172, 1.085937649122431, 1.09122...    14.642  ...
# 4     [1.7309675801735431, 1.030987195964759, 1.1015...    14.030  ...
# ...                                                 ...       ...  ...
# 1785  [2.2846011835800297, 1.1570531332525222, 1.105...    14.908  ...
# 1786  [1.8251926197192418, 1.0972410606592737, 1.082...    14.201  ...
# 1787  [1.781075993991352, 1.07905696524328, 1.082869...    14.718  ...
# 1788  [1.8510805961570183, 1.0347360871623914, 1.090...    15.137  ...
# 1789  [1.962478117625136, 1.0904708814873694, 1.0887...    15.185  ...
#
#       Magnesium  Oxygen  Potassium  Silicon  Thorium  Titanium  Uranium  \
# 0        3.5168  45.289     299.99   20.793  0.46453   0.17034  0.17684
# 1        4.2240  45.529     376.77   22.029  0.65727   0.11806  0.14017
# 2        3.5352  44.660     375.20   20.907  0.59783   0.16417  0.25209
# 3        3.6490  44.706     255.60   20.687  0.44024   0.21359  0.15456
# 4        3.4253  44.777     299.84   20.930  0.41695   0.00000  0.17853
# ...         ...     ...        ...      ...      ...       ...      ...
# 1785     4.8716  44.940     935.92   20.180  1.65770   0.11112  0.47992
# 1786     4.9509  45.074     725.37   20.989  1.47520   0.23089  0.31377
# 1787     3.5729  44.902     615.29   20.763  1.13880   0.14168  0.36836
# 1788     3.4631  45.209     534.21   20.913  0.92528   0.14485  0.24324
# 1789     4.2786  44.799     714.98   20.098  1.31050   0.14671  0.41704
#
#                             Denoised Log Scaled Spectra  \
# 0     [2.158214838616408, 2.157544331369737, 2.15556...
# 1     [2.166600464940364, 2.1658480356144825, 2.1637...
# 2     [2.1624604406884194, 2.1617557577637347, 2.159...
# 3     [2.156835106449848, 2.156137776072336, 2.15427...
# 4     [2.1550525786763455, 2.15430812063849, 2.15245...
# ...                                                 ...
# 1785  [2.15549824869262, 2.1548999596086973, 2.15302...
# 1786  [2.14741575183071, 2.14686561246586, 2.1451899...
# 1787  [2.1464838830391613, 2.1458006278534687, 2.143...
# 1788  [2.1390119880861276, 2.138304773247351, 2.1364...
# 1789  [2.1479502451595986, 2.147254910678402, 2.1453...
#
#           Continuum Removed Denoised Log Scaled Spectra  \
# 0     [0.0, 0.0031096864344261066, 0.005679290051129...
# 1     [0.0, 0.0031162181188209015, 0.005685493606940...
# 2     [0.0, 0.003128077634203974, 0.0057268713902404...
# 3     [0.0, 0.0031223821127568385, 0.005761526562635...
# 4     [0.0, 0.0030380779680346803, 0.005615903444584...
# ...                                                 ...
# 1785  [0.0, 0.0031042509343501834, 0.005683791947784...
# 1786  [0.0, 0.003080477682960492, 0.0056969814199795...
# 1787  [0.0, 0.003018919479894744, 0.0055261654685280...
# 1788  [0.0, 0.0029927682042373283, 0.005525986008764...
# 1789  [0.0, 0.003031719365600205, 0.0055773123862935...
#
#      Normalized Continuum Removed Denoised Log Scaled Spectra
# 0     [0.0, 0.008732596361173385, 0.0159485365101445...
# 1     [0.0, 0.00854362748004175, 0.01558772125881830...
# 2     [0.0, 0.008671523159558032, 0.0158757881675521...
# 3     [0.0, 0.008548415452029046, 0.0157738293766423...
# 4     [0.0, 0.00860571082569534, 0.01590770269151066...
# ...                                                 ...
# 1785  [0.0, 0.008672476703310141, 0.0158790491800041...
# 1786  [0.0, 0.008773223933367814, 0.0162250465303427...
# 1787  [0.0, 0.008498570047967925, 0.0155567263862845...
# 1788  [0.0, 0.008238164470285638, 0.0152113289416292...
# 1789  [0.0, 0.008583538074052393, 0.0157907337208821...
#
# [1790 rows x 22 columns]

# %%
#create a variable epsilon, which contains a very small value that is added to all inputs and outputs to make sure no values are 0
epsilon=1e-8

# %%
#get the abundance values for the seven elements for which the model is to be trained
#aluminium
aluminiumAbundances=dataframe['Aluminum'].to_numpy()+epsilon
#calcium
calciumAbundances=dataframe['Calcium'].to_numpy()+epsilon
#iron
ironAbundances=dataframe['Iron'].to_numpy()+epsilon
#magnesium
magnesiumAbundances=dataframe['Magnesium'].to_numpy()+epsilon
#oxygen
oxygenAbundances=dataframe['Oxygen'].to_numpy()+epsilon
#silicon
siliconAbundances=dataframe['Silicon'].to_numpy()+epsilon
#titanium
titaniumAbundances=dataframe['Titanium'].to_numpy()+epsilon

# %%
#get abundance values for the three nuclear elements
potassiumAbundances=dataframe['Potassium'].to_numpy()+epsilon
thoriumAbundances=dataframe['Thorium'].to_numpy()+epsilon
uraniumAbundances=dataframe['Uranium'].to_numpy()+epsilon

# %%
#scale nuclear abundance values between 0 and 1
potassiumAbundances=(potassiumAbundances-np.amin(potassiumAbundances))/np.ptp(potassiumAbundances)
thoriumAbundances=(thoriumAbundances-np.amin(thoriumAbundances))/np.ptp(thoriumAbundances)
uraniumAbundances=(uraniumAbundances-np.amin(uraniumAbundances))/np.ptp(uraniumAbundances)

# %%
#create an list which contains the element names to be estimated
regularElementNames=['Aluminum',
                     'Calcium',
                     'Iron',
                     'Magnesium',
                     'Oxygen',
                     'Silicon',
                     'Titanium']
#conver the list to a numpy array
regularElementNames=np.array(regularElementNames)

# %%
#combine the elemental abundances into a single matrix
regularElementalAbundances=np.dstack([aluminiumAbundances,
                                      calciumAbundances,
                                      ironAbundances,
                                      magnesiumAbundances,
                                      oxygenAbundances,
                                      siliconAbundances,
                                      titaniumAbundances])
#reshape the abundance matrix
regularElementalAbundances=regularElementalAbundances[0,:,:]
#rescale weigth percent values from % (0-100) to franctions (0-1)
regularElementalAbundances=regularElementalAbundances/100

# %%
#create an list which contains the element names to be estimated
nuclearElementNames=['Potassium',
                     'Thorium',
                     'Uranium']
#conver the list to a numpy array
nuclearElementNames=np.array(nuclearElementNames)

# %%
#create an array containing the names of all elements
allElementNames=np.hstack([regularElementNames,nuclearElementNames])

# %%
#combine the elemental abundances into a single matrix
nuclearElementalAbundances=np.dstack([potassiumAbundances,
                                      thoriumAbundances,
                                      uraniumAbundances])
#reshape the abundance matrix
nuclearElementalAbundances=nuclearElementalAbundances[0,:,:]

# %%
#read the pre-processed spectra as a numpy array
preprocessedSpectra=dataframe['Normalized Continuum Removed Denoised Log Scaled Spectra'].to_numpy()
#reshape the numpy array
preprocessedSpectra=np.vstack(preprocessedSpectra)+epsilon

# %%
#compute the eneergy values for each band
gain=17.8 #keV/channel
energyBands=np.arange(0,512,1)*gain

# %%
#get the index of the last relavent band
finalRelaventBandIndex=np.argmin(np.abs(energyBands-8000))
#compute the index of the first relavent band
firstRelaventBandIndex=finalRelaventBandIndex-preprocessedSpectra.shape[1]+1
#get the energies of the relavent bands
relaventEnergyBands=energyBands[firstRelaventBandIndex:finalRelaventBandIndex+1]

# %%
#remove the variables no longer needed from memory
del firstRelaventBandIndex
del finalRelaventBandIndex
del energyBands
del gain
del dataframe
del dataFramePickleAddress
del aluminiumAbundances
del calciumAbundances
del ironAbundances
del magnesiumAbundances
del oxygenAbundances
del siliconAbundances
del titaniumAbundances

# %%
#import pyplot from matplotlib
import matplotlib.pyplot as plt

# %%
#set plot parameters
baseFontSize=18
noOfBinsForHistogram=100
noOfXticks=5

# %%
#create a figure 
figure,axes=plt.subplots(nrows=1,
                         ncols=7,
                         figsize=(35,5),
                         dpi=200)
#iterate over all elements
for i in range(regularElementNames.shape[0]):
    #plot the histogram
    temp=axes[i].hist(regularElementalAbundances[:,i],
                      bins=noOfBinsForHistogram)
    #set the title of the figure
    axes[i].set_title(regularElementNames[i],fontsize=baseFontSize*1.2)
    #set the axis labels
    axes[i].set_xlabel("Wt frac.",fontsize=baseFontSize*1.2)
    axes[i].set_ylabel("Freq",fontsize=baseFontSize*1.2)
    #set the ticks and their label sizes
    axes[i].set_xticks(np.arange(np.amin(regularElementalAbundances[:,i]),
                                 np.amax(regularElementalAbundances[:,i])+np.ptp(regularElementalAbundances[:,i])/noOfXticks,
                                 np.ptp(regularElementalAbundances[:,i])/noOfXticks),
                       labels=np.round(np.arange(np.amin(regularElementalAbundances[:,i]),
                                                 np.amax(regularElementalAbundances[:,i])+np.ptp(regularElementalAbundances[:,i])/noOfXticks,
                                                 np.ptp(regularElementalAbundances[:,i])/noOfXticks),
                                       2),
                       fontsize=baseFontSize)
    #set the margins
    axes[i].margins(0.01)
    
#add a title
figure.suptitle("Distribution of abundance values",
                fontsize=baseFontSize*1.5)
#adjust the layout
plt.tight_layout()

# %%
#create a figure 
figure,axes=plt.subplots(nrows=1,
                         ncols=3,
                         figsize=(15,5),
                         dpi=200)
#iterate over all elements
for i in range(nuclearElementNames.shape[0]):
    #plot the histogram
    temp=axes[i].hist(nuclearElementalAbundances[:,i],
                      bins=noOfBinsForHistogram)
    #set the title of the figure
    axes[i].set_title(nuclearElementNames[i],fontsize=baseFontSize*1.2)
    #set the axis labels
    axes[i].set_xlabel("PPM",fontsize=baseFontSize*1.2)
    axes[i].set_ylabel("Freq",fontsize=baseFontSize*1.2)
    #set the ticks and their label sizes
    axes[i].set_xticks(np.arange(np.amin(nuclearElementalAbundances[:,i]),
                                 np.amax(nuclearElementalAbundances[:,i])+np.ptp(nuclearElementalAbundances[:,i])/noOfXticks,
                                 np.ptp(nuclearElementalAbundances[:,i])/noOfXticks),
                       labels=np.round(np.arange(np.amin(nuclearElementalAbundances[:,i]),
                                                 np.amax(nuclearElementalAbundances[:,i])+np.ptp(nuclearElementalAbundances[:,i])/noOfXticks,
                                                 np.ptp(nuclearElementalAbundances[:,i])/noOfXticks),
                                       2),
                       fontsize=baseFontSize)
    #set the margins
    axes[i].margins(0.01)
    
#add a title
figure.suptitle("Distribution of abundance values",
                fontsize=baseFontSize*1.5)
#adjust the layout
plt.tight_layout()

# %%
#create a figure
plt.figure(figsize=(30,15),
           dpi=100)
#and plot all the spectra
for i in range(preprocessedSpectra.shape[0]):
    plt.plot(relaventEnergyBands,
             preprocessedSpectra[i,:],
             lw=5)
#annotate the figure
plt.title("Preprocessed GRS Spectra",
          fontsize=baseFontSize*1.8)
plt.xticks(np.arange(np.amin(relaventEnergyBands),
                     np.amax(relaventEnergyBands)+np.ptp(relaventEnergyBands)/noOfXticks,
                     np.ptp(relaventEnergyBands)/noOfXticks),
           fontsize=baseFontSize*1.2)
plt.yticks(np.arange(np.amin(preprocessedSpectra),
                     np.amax(preprocessedSpectra)+np.ptp(preprocessedSpectra)/noOfXticks,
                     np.ptp(preprocessedSpectra)/noOfXticks),
           labels=np.round(np.arange(np.amin(preprocessedSpectra),
                                     np.amax(preprocessedSpectra)+np.ptp(preprocessedSpectra)/noOfXticks,
                                     np.ptp(preprocessedSpectra)/noOfXticks),
                           2),
           fontsize=baseFontSize*1.2)
plt.xlabel("KeV",
           fontsize=baseFontSize*1.5)
plt.ylabel("log(Counts/min) ratioed",
           fontsize=baseFontSize*1.5)
plt.margins(0)

# %%
#import PCA from sklearn
from sklearn.decomposition import PCA
#import cosine distance from scipy
from scipy.spatial.distance import cosine as cosineDistance

#define a function which given an array of spectra, explained-variance ratio, and no of spectra to be selected
#returns the indices of most interesting (most unlike the others) spectra
def extractMostExtremeSpectraWithDEMUD(spectra,varianceToExplain,noOfSpectraToRetrive):
    #create an array to hold the indices of the selected (interesting) super-pixels
    selectedSpectraIndices=[]
    #create a PCA object which explains over 95% of the variance in the data
    pcaObject=PCA(n_components=varianceToExplain,
                  svd_solver='auto')
    #compute the PCA model for the spectra and use it to reconstruct the orginal spectra
    reconstructedSpectra=pcaObject.inverse_transform(pcaObject.fit_transform(spectra))
    #create an array to save the reconstruction error (cosine distance)
    reconstructionErrors=np.full(spectra.shape[0],
                                 np.nan)
    #compute the cosine distance between the orginal and reconstructed spectra
    for i in range(spectra.shape[0]):
        reconstructionErrors[i]=cosineDistance(spectra[i,:],
                                               reconstructedSpectra[i,:])
    #save the index of the spectra with the greatest error
    selectedSpectraIndices.append(np.argmax(reconstructionErrors))

    #iteratively extract the most dissimar spectra
    for i in range(noOfSpectraToRetrive-1):
        #fit PCA to the selected spectra
        pcaObject.fit(spectra[selectedSpectraIndices,:])
        #apply PCA and then reconstruct the spectra
        reconstructedSpectra=pcaObject.inverse_transform(pcaObject.transform(spectra))
        #create an array to save the reconstruction error (cosine distance)
        reconstructionErrors=np.full(spectra.shape[0],np.nan)
        #compute the cosine distance between the orginal and reconstructed spectra
        for i in range(spectra.shape[0]):
            reconstructionErrors[i]=cosineDistance(spectra[i,:],
                                                   reconstructedSpectra[i,:])
        #remove the error of the selected pixels
        reconstructionErrors=np.delete(reconstructionErrors,
                                       selectedSpectraIndices)
        #get the index of the spectra with the greatest error
        selectedSpectraIndices.append(np.delete(np.arange(0,spectra.shape[0],1),
                                                selectedSpectraIndices,axis=0)[np.argmax(reconstructionErrors)])
        
    return selectedSpectraIndices

# %%
#set parameters for extracting differing spectra
varianceToBeExplainedDuringDEMUD=0.95
noOfExtremeSpectraToBeRetrieved=179
#get indices of the most extreme spectra
extremeIndices=extractMostExtremeSpectraWithDEMUD(preprocessedSpectra,
                                                  varianceToExplain=varianceToBeExplainedDuringDEMUD,
                                                  noOfSpectraToRetrive=noOfExtremeSpectraToBeRetrieved)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\decomposition\_pca.py:543: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ = (S**2) / (n_samples - 1)

# %%
#get the subset data
#spectra
preprocessedSpectra=preprocessedSpectra[extremeIndices,:]
#regular abundances
regularElementalAbundances=regularElementalAbundances[extremeIndices,:]
#nuclear abundances
nuclearElementalAbundances=nuclearElementalAbundances[extremeIndices,:]

# %%
#create a figure 
figure,axes=plt.subplots(nrows=1,
                         ncols=7,
                         figsize=(35,5),
                         dpi=200)
#iterate over all elements
for i in range(regularElementNames.shape[0]):
    #plot the histogram
    temp=axes[i].hist(regularElementalAbundances[:,i],
                      bins=noOfBinsForHistogram)
    #set the title of the figure
    axes[i].set_title(regularElementNames[i],fontsize=baseFontSize*1.2)
    #set the axis labels
    axes[i].set_xlabel("Wt frac.",fontsize=baseFontSize*1.2)
    axes[i].set_ylabel("Freq",fontsize=baseFontSize*1.2)
    #set the ticks and their label sizes
    axes[i].set_xticks(np.arange(np.amin(regularElementalAbundances[:,i]),
                                 np.amax(regularElementalAbundances[:,i])+np.ptp(regularElementalAbundances[:,i])/noOfXticks,
                                 np.ptp(regularElementalAbundances[:,i])/noOfXticks),
                       labels=np.round(np.arange(np.amin(regularElementalAbundances[:,i]),
                                                 np.amax(regularElementalAbundances[:,i])+np.ptp(regularElementalAbundances[:,i])/noOfXticks,
                                                 np.ptp(regularElementalAbundances[:,i])/noOfXticks),
                                       2),
                       fontsize=baseFontSize)
    #set the margins
    axes[i].margins(0.01)
    
#add a title
figure.suptitle("Distribution of abundance values",
                fontsize=baseFontSize*1.5)
#adjust the layout
plt.tight_layout()

# %%
#create a figure 
figure,axes=plt.subplots(nrows=1,
                         ncols=3,
                         figsize=(15,5),
                         dpi=200)
#iterate over all elements
for i in range(nuclearElementNames.shape[0]):
    #plot the histogram
    temp=axes[i].hist(nuclearElementalAbundances[:,i],
                      bins=noOfBinsForHistogram)
    #set the title of the figure
    axes[i].set_title(nuclearElementNames[i],fontsize=baseFontSize*1.2)
    #set the axis labels
    axes[i].set_xlabel("PPM",fontsize=baseFontSize*1.2)
    axes[i].set_ylabel("Freq",fontsize=baseFontSize*1.2)
    #set the ticks and their label sizes
    axes[i].set_xticks(np.arange(np.amin(nuclearElementalAbundances[:,i]),
                                 np.amax(nuclearElementalAbundances[:,i])+np.ptp(nuclearElementalAbundances[:,i])/noOfXticks,
                                 np.ptp(nuclearElementalAbundances[:,i])/noOfXticks),
                       labels=np.round(np.arange(np.amin(nuclearElementalAbundances[:,i]),
                                                 np.amax(nuclearElementalAbundances[:,i])+np.ptp(nuclearElementalAbundances[:,i])/noOfXticks,
                                                 np.ptp(nuclearElementalAbundances[:,i])/noOfXticks),
                                       2),
                       fontsize=baseFontSize)
    #set the margins
    axes[i].margins(0.01)
    
#add a title
figure.suptitle("Distribution of abundance values",
                fontsize=baseFontSize*1.5)
#adjust the layout
plt.tight_layout()

# %%
#create a figure
plt.figure(figsize=(30,15),
           dpi=100)
#and plot all the spectra
for i in range(preprocessedSpectra.shape[0]):
    plt.plot(relaventEnergyBands,
             preprocessedSpectra[i,:],
             lw=5)
#annotate the figure
plt.title("Preprocessed GRS Spectra",
          fontsize=baseFontSize*1.8)
plt.xticks(np.arange(np.amin(relaventEnergyBands),
                     np.amax(relaventEnergyBands)+np.ptp(relaventEnergyBands)/noOfXticks,
                     np.ptp(relaventEnergyBands)/noOfXticks),
           fontsize=baseFontSize*1.2)
plt.yticks(np.arange(np.amin(preprocessedSpectra),
                     np.amax(preprocessedSpectra)+np.ptp(preprocessedSpectra)/noOfXticks,
                     np.ptp(preprocessedSpectra)/noOfXticks),
           labels=np.round(np.arange(np.amin(preprocessedSpectra),
                                     np.amax(preprocessedSpectra)+np.ptp(preprocessedSpectra)/noOfXticks,
                                     np.ptp(preprocessedSpectra)/noOfXticks),
                           2),
           fontsize=baseFontSize*1.2)
plt.xlabel("KeV",
           fontsize=baseFontSize*1.5)
plt.ylabel("log(Counts/min) ratioed",
           fontsize=baseFontSize*1.5)
plt.margins(0)

# %%
#import tensorflow
import tensorflow as tf

# %%
#set a global seed value
globalSeed=23

# %%
#compute the number of channels in the pre-processed spectra
noOfChannels=preprocessedSpectra.shape[1]

# %%
#create an input layer
inputLayer=tf.keras.Input(shape=(noOfChannels,
                                 1))

# %%
#create a function which given a feature volume, applies a single convolutional block to it
#the convolution block consists of
#Convolutional layer; Activation; Batch Normalization; Dropout
#the number of filters, their sizes, strideactivation function, and dropout rate are specified
def createConvolutionalBlock(inputVolume,noOfFilters,kernelSize,strideSize,dropoutRate):
    #create a convolutional block
    convolutionalLayer=tf.keras.layers.Conv1D(filters=noOfFilters,
                                                   kernel_size=kernelSize,
                                                   strides=strideSize,
                                                   padding='valid')
    #add the 1st Conv layer to the graph
    volume=convolutionalLayer(inputVolume)

    #apply Relu activation
    preluActivation=tf.keras.layers.PReLU()
    #add the 1st activation layer to the graph
    volume=preluActivation(volume)

    #apply batch normalization
    batchNormalization=tf.keras.layers.BatchNormalization()
    #add the 1st batch-norm layer to the graph
    volume=batchNormalization(volume)

    #apply dropout
    dropoutLayer=tf.keras.layers.Dropout(dropoutRate,
                                         noise_shape=None,
                                         seed=globalSeed)
    #add the 1st dropout layer to the graph
    volume=dropoutLayer(volume)
    
    return volume

# %%
#create a list containing the number of features to be outputted by each Conv block
noOfChannelsInEachConvBlock=[128,256,512,1024]
#create a list containing the sizes filter for each Conv block
filterSizesForEachConvBlock=[7,5,3,3]
#create a list containing the strides for each Conv block
strideSizesForEachConvBlock=[3,3,2,2]
#create a list containing the dropout rate for each Conv block
dropoutForEachConvBlock=[0.5,0.5,0.5,0.5]

# %%
#create a NN (Neural Network) graph containing just the input layer
regularElementFeatures=inputLayer
nuclearElementFeatures=inputLayer

# %%
#add Convolutional blocks to create the feature extractor for regular elements

for i in range(len(noOfChannelsInEachConvBlock)):
    #create a convolutional block
    regularElementFeatures=createConvolutionalBlock(regularElementFeatures,
                                                    noOfChannelsInEachConvBlock[i],
                                                    filterSizesForEachConvBlock[i],
                                                    strideSizesForEachConvBlock[i],
                                                    dropoutForEachConvBlock[i])
    
    print(f"Shape of the tensor outputted by the 0th Conv. Block {regularElementFeatures.shape}")
# Out:
# Shape of the tensor outputted by the 0th Conv. Block (None, 139, 128)
# Shape of the tensor outputted by the 0th Conv. Block (None, 45, 256)
# Shape of the tensor outputted by the 0th Conv. Block (None, 22, 512)
# Shape of the tensor outputted by the 0th Conv. Block (None, 10, 1024)

# %%
#Flatten the features for the regular elemnents
regularElementFeatures=tf.keras.layers.Flatten()(regularElementFeatures)
print(f"Shape of flattened features {regularElementFeatures.shape}")
# Out:
# Shape of flattened features (None, 10240)

# %%
#create a list containing the number of features to be outputted by each Conv block
noOfChannelsInEachConvBlock=[128,256,512]
#create a list containing the sizes filter for each Conv block
filterSizesForEachConvBlock=[7,5,3]
#create a list containing the strides for each Conv block
strideSizesForEachConvBlock=[3,3,2]
#create a list containing the dropout rate for each Conv block
dropoutForEachConvBlock=[0.5,0.5,0.5]

# %%
#add Convolutional blocks to create the feature extractor for regular elements

for i in range(len(noOfChannelsInEachConvBlock)):
    #create a convolutional block
    nuclearElementFeatures=createConvolutionalBlock(nuclearElementFeatures,
                                                    noOfChannelsInEachConvBlock[i],
                                                    filterSizesForEachConvBlock[i],
                                                    strideSizesForEachConvBlock[i],
                                                    dropoutForEachConvBlock[i])
    
    print(f"Shape of the tensor outputted by the 0th Conv. Block {nuclearElementFeatures.shape}")
# Out:
# Shape of the tensor outputted by the 0th Conv. Block (None, 139, 128)
# Shape of the tensor outputted by the 0th Conv. Block (None, 45, 256)
# Shape of the tensor outputted by the 0th Conv. Block (None, 22, 512)

# %%
#Flatten the features for the nuclear elements
nuclearElementFeatures=tf.keras.layers.Flatten()(nuclearElementFeatures)
print(f"Shape of flattened features {nuclearElementFeatures.shape}")
# Out:
# Shape of flattened features (None, 11264)

# %%
#get the regular elements' abundances from the generated features
#it consists of three steps
#1. Apply a dense layer with 7 nodes without any activation
#2. Compute the absolute value of the values computed by dense layer
#3. Compute the l1-norm of the 7 regular elements and and divide them by it

# %%
#define a function which given the output of a layer, ensures the sum of the values is one
#it does this by computing the sum of the nodes and dividing each note by it
def estimateAbundances(inputNodes,name):
    sampleWiseSums=tf.keras.backend.sum(inputNodes,
                                        axis=-1,
                                        keepdims=True)
    sampleWiseSums=tf.repeat(sampleWiseSums,
                             sampleWiseSums.shape[-1],
                             axis=-1)
    return tf.math.divide(inputNodes,
                          sampleWiseSums+1e-10,
                          name=name)

# %%
#add a fully connected layer to the network (output layer)
regularElementStage1=tf.keras.layers.Dense(7,activation='relu')(regularElementFeatures)

#add a normalization layer to the network
regularAbundanceEmbedding=tf.nn.softmax(regularElementStage1,
                                        name="Regular_Abundances")


#print shape of abundances
print(f"Unscaled regular element shape {regularAbundanceEmbedding.shape}")
# Out:
# Unscaled regular element shape (None, 7)

# %%
#get the abundances for the nuclear elements from their features
nuclearAbundanceEmbedding=tf.keras.layers.Dense(3,activation='relu',name="Nuclear_Abundances")(nuclearElementFeatures)
#print shape of abundances
print(f"Unscaled regular element shape {nuclearAbundanceEmbedding.shape}")
# Out:
# Unscaled regular element shape (None, 3)

# %%
#concattenate the two abundances
fullAbundanceEmbedding=tf.concat([regularAbundanceEmbedding,nuclearAbundanceEmbedding],
                                 axis=-1)

print(f"All element shape {fullAbundanceEmbedding.shape}")
# Out:
# All element shape (None, 10)

# %%
#define regularization for the element-wise spectra
#the regularizer encourages the elemental spectra to be different
#this is done by computing the pairwise cosine distances, summing them up and maximizing this sum

#as these weights are from seperate (parallel)layers this regularization could not be implemented as inheriting the kernel regularization class
#therefore it is implemented as a loss. As such it recieves the true and predicted values but ignores them
class spectralDisimilarityRegularization(tf.keras.losses.Loss):
    def call(self,linearLayerWeights,_):
        #normalize the weights
        linearLayerWeights=tf.math.l2_normalize(linearLayerWeights,
                                                axis=-2,
                                                epsilon=1e-1)

        #multiply the weights by their transpose to get the dot products (provided the weight vectors have an l2-norm of 1)
        #sum the dot products up to get a value proportional to the sum of pairwise dot products
        unmixingSpectralSimilarity=tf.math.reduce_sum(tf.linalg.matmul(linearLayerWeights,
                                                                       linearLayerWeights,
                                                                       transpose_b=True))
        #compute sum of cosine similarities by subtracting the number of sames from the data and then dividing by half
        unmixingSpectralSimilarity=(unmixingSpectralSimilarity-linearLayerWeights.shape[-1])/2

        #return the similarity estimate which is the regularization value
        return unmixingSpectralSimilarity

# %%
#create a composite constraint to be applied to the weights of the hidden layers which are the weights
class UnitNormNonNegetivityConstraint(tf.keras.constraints.Constraint):
    def __init__(self,axis=0):
        self.axis=axis
    def __call__(self, w):
        #apply positivity constraint
        w=w*tf.cast(tf.greater_equal(w,0.0),
                    tf.keras.backend.floatx())
        
        return w



#create the composite constraint by combining the two constraints
unitNormNonNegetivityConstraint=UnitNormNonNegetivityConstraint()

# %%
#create the linear hidden layer as a combination of ten hidden layers each connected to a single abundance value
elementWiseHiddenLayers=[]
abundanceScaledElementalSpectra=[]
for i in range(fullAbundanceEmbedding.shape[-1]):
    temp=tf.keras.layers.Dense(noOfChannels,activation=None,use_bias=False,kernel_constraint=unitNormNonNegetivityConstraint,name=allElementNames[i]+"_Spectra")
    elementWiseHiddenLayers.append(temp)
    temp=temp(tf.expand_dims(fullAbundanceEmbedding[:,i],-1))
    abundanceScaledElementalSpectra.append(temp)
    del temp
    print(f"Shape of the spectra outputed by {allElementNames[i]} {abundanceScaledElementalSpectra[-1].shape}")
# Out:
# Shape of the spectra outputed by Aluminum (None, 421)
# Shape of the spectra outputed by Calcium (None, 421)
# Shape of the spectra outputed by Iron (None, 421)
# Shape of the spectra outputed by Magnesium (None, 421)
# Shape of the spectra outputed by Oxygen (None, 421)
# Shape of the spectra outputed by Silicon (None, 421)
# Shape of the spectra outputed by Titanium (None, 421)
# Shape of the spectra outputed by Potassium (None, 421)
# Shape of the spectra outputed by Thorium (None, 421)
# Shape of the spectra outputed by Uranium (None, 421)

# %%
#stack the abundance scaled elemental spectra together
abundanceScaledElementalSpectra=tf.stack(abundanceScaledElementalSpectra,axis=-1)
print(f"Shape of tensor containing all ten elemental spectra {abundanceScaledElementalSpectra.shape}")
# Out:
# Shape of tensor containing all ten elemental spectra (None, 421, 10)

# %%
#add the element wise spectra
linearMixedSpectra=tf.keras.backend.sum(abundanceScaledElementalSpectra,
                                        axis=-1,
                                        keepdims=False)
print(f"Shape of the linearly mixed spectra {linearMixedSpectra.shape}")
# Out:
# Shape of the linearly mixed spectra (None, 421)

# %%
#build the model
unmixingModel=tf.keras.Model(inputs=inputLayer,
                             outputs=[regularAbundanceEmbedding,
                                      nuclearAbundanceEmbedding,
                                      linearMixedSpectra,
                                      abundanceScaledElementalSpectra],
                             name="Regularized_Constrained_Dual_Encoder_Unmxing_Model")

# %%
#create loss functions for the embeddings, Mean Squared Error
regularAbundanceLossFunction=tf.keras.losses.MeanSquaredError()
nuclearAbundanceLossFunction=tf.keras.losses.MeanSquaredError()
#create the loss function for the reconstructed spectra, Cosine loss
recontructedSpectraLoss=tf.keras.losses.CosineSimilarity()
#create the optimizer
optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3)
#set the number of epochs the model is to be trained for
noOfEpochs=300
#set the batch size
batchSize=179

#create the regularizer
spectralDisimilarityRegularizer=spectralDisimilarityRegularization()

# %%
#create a loss dictionary
lossDictionary=[regularAbundanceLossFunction,
                nuclearAbundanceLossFunction,
                recontructedSpectraLoss,
                spectralDisimilarityRegularizer]

# %%
#creat a list with loss weights
lossWeights=[1e-2,
             1,
             1e-5,
             1e-3]

# %%
#compile the model
unmixingModel.compile(optimizer=optimizer,
                      loss=lossDictionary,
                      loss_weights=lossWeights)

# %%
#set the address where the untrained model will be saved
#untrainedModelWeightsAddress="C:/ML4Sci/Ml4Sci_GRS_abundance_estimation/Models/untrained_Regularized_Constrainted_Dual_Unmixing_Model_With_PReLU_Weights.h5"
untrainedModelWeightsAddress="D:/Non-academic/GSOC23/untrained_Regularized_Constrainted_Dual_Unmixing_Model_With_PReLU_Weights_and_Linear_Decoder.h5"

# %%
#save the untrained model
unmixingModel.save_weights(untrainedModelWeightsAddress,
                           overwrite=True)

# %%
#check if the GPU is available
if len(tf.config.list_physical_devices('GPU'))==1:
    print("GPU available")
else:
    print("GPU unavailable")
# Out:
# GPU unavailable

# %%
noOfXticks=3
noOfYticks=5

# %%
#create an array to save the element-wise learnt spectra across folds
learntElementalSpectra=np.zeros((noOfChannels,
                                 fullAbundanceEmbedding.shape[-1]))

# %%
unmixingModel.load_weights(untrainedModelWeightsAddress)
#compile the model
unmixingModel.compile(optimizer=optimizer,
                      loss=lossDictionary,
                      loss_weights=lossWeights)

#fit the model to the current fold's data
currentModelTrainingHistory=unmixingModel.fit(x=preprocessedSpectra,
                                                        y=[regularElementalAbundances,
                                                           nuclearElementalAbundances,
                                                           preprocessedSpectra,
                                                           nuclearElementalAbundances],
                                                        batch_size=batchSize,
                                                        epochs=noOfEpochs)


#save the training history of the current model
modelTrainingHistories.append(currentModelTrainingHistory)



#set the address where the untrained model will be saved
trainedModelWeightsAddress="D:/Non-academic/GSOC23/trained_Regularized_Constrainted_Dual_Unmixing_Model_With_PReLU_Weights_and_Linear_Decoder.h5"

#save the untrained model
unmixingModel.save_weights(trainedModelWeightsAddress,
                           overwrite=True)
# Out:
# Epoch 1/300
# 1/1 [==============================] - 6s 6s/step - loss: 1.6379 - tf.nn.softmax_loss: 0.0495 - Nuclear_Abundances_loss: 1.5283 - tf.math.reduce_sum_loss: 0.0098 - tf.stack_loss: 109.0104
# Epoch 2/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1660 - tf.nn.softmax_loss: 0.0246 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.5164 - tf.stack_loss: 109.0104
# Epoch 3/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0195 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.5656 - tf.stack_loss: 109.0104
# Epoch 4/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0173 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6116 - tf.stack_loss: 109.0104
# Epoch 5/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0183 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6158 - tf.stack_loss: 109.0104
# Epoch 6/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0184 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6233 - tf.stack_loss: 109.0104
# Epoch 7/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0182 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6239 - tf.stack_loss: 109.0104
# Epoch 8/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0183 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6221 - tf.stack_loss: 109.0104
# Epoch 9/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0171 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6210 - tf.stack_loss: 109.0104
# Epoch 10/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0176 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6000 - tf.stack_loss: 109.0104
# Epoch 11/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0184 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.5689 - tf.stack_loss: 109.0104
# Epoch 12/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0162 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.5877 - tf.stack_loss: 109.0104
# Epoch 13/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0161 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6117 - tf.stack_loss: 109.0104
# Epoch 14/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0160 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6210 - tf.stack_loss: 109.0104
# Epoch 15/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0169 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6328 - tf.stack_loss: 109.0104
# Epoch 16/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0165 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6158 - tf.stack_loss: 109.0104
# Epoch 17/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0176 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6043 - tf.stack_loss: 109.0104
# Epoch 18/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0180 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.5886 - tf.stack_loss: 109.0104
# Epoch 19/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0151 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6191 - tf.stack_loss: 109.0104
# Epoch 20/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0163 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6207 - tf.stack_loss: 109.0104
# Epoch 21/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0164 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6241 - tf.stack_loss: 109.0104
# Epoch 22/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0167 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6304 - tf.stack_loss: 109.0104
# Epoch 23/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0165 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6358 - tf.stack_loss: 109.0104
# Epoch 24/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0175 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6243 - tf.stack_loss: 109.0104
# Epoch 25/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0159 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6221 - tf.stack_loss: 109.0104
# Epoch 26/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0173 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6156 - tf.stack_loss: 109.0104
# Epoch 27/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0168 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6197 - tf.stack_loss: 109.0104
# Epoch 28/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0163 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6381 - tf.stack_loss: 109.0104
# Epoch 29/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0174 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6440 - tf.stack_loss: 109.0104
# Epoch 30/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0167 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6584 - tf.stack_loss: 109.0104
# Epoch 31/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0183 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6591 - tf.stack_loss: 109.0104
# Epoch 32/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0171 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6579 - tf.stack_loss: 109.0104
# Epoch 33/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0161 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6464 - tf.stack_loss: 109.0104
# Epoch 34/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0177 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6330 - tf.stack_loss: 109.0104
# Epoch 35/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0184 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6257 - tf.stack_loss: 109.0104
# Epoch 36/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0184 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6410 - tf.stack_loss: 109.0104
# Epoch 37/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0182 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6726 - tf.stack_loss: 109.0104
# Epoch 38/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0191 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6803 - tf.stack_loss: 109.0104
# Epoch 39/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6824 - tf.stack_loss: 109.0104
# Epoch 40/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6845 - tf.stack_loss: 109.0104
# Epoch 41/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6866 - tf.stack_loss: 109.0104
# Epoch 42/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6887 - tf.stack_loss: 109.0104
# Epoch 43/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6909 - tf.stack_loss: 109.0104
# Epoch 44/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6931 - tf.stack_loss: 109.0104
# Epoch 45/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6952 - tf.stack_loss: 109.0104
# Epoch 46/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6974 - tf.stack_loss: 109.0104
# Epoch 47/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.6996 - tf.stack_loss: 109.0104
# Epoch 48/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7018 - tf.stack_loss: 109.0104
# Epoch 49/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7040 - tf.stack_loss: 109.0104
# Epoch 50/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7062 - tf.stack_loss: 109.0104
# Epoch 51/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7084 - tf.stack_loss: 109.0104
# Epoch 52/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7106 - tf.stack_loss: 109.0104
# Epoch 53/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7128 - tf.stack_loss: 109.0104
# Epoch 54/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7150 - tf.stack_loss: 109.0104
# Epoch 55/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7173 - tf.stack_loss: 109.0104
# Epoch 56/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7195 - tf.stack_loss: 109.0104
# Epoch 57/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7217 - tf.stack_loss: 109.0104
# Epoch 58/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7239 - tf.stack_loss: 109.0104
# Epoch 59/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7261 - tf.stack_loss: 109.0104
# Epoch 60/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7283 - tf.stack_loss: 109.0104
# Epoch 61/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7305 - tf.stack_loss: 109.0104
# Epoch 62/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7327 - tf.stack_loss: 109.0104
# Epoch 63/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7349 - tf.stack_loss: 109.0104
# Epoch 64/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7371 - tf.stack_loss: 109.0104
# Epoch 65/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7393 - tf.stack_loss: 109.0104
# Epoch 66/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7415 - tf.stack_loss: 109.0104
# Epoch 67/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7436 - tf.stack_loss: 109.0104
# Epoch 68/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7458 - tf.stack_loss: 109.0104
# Epoch 69/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7480 - tf.stack_loss: 109.0104
# Epoch 70/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7501 - tf.stack_loss: 109.0104
# Epoch 71/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7522 - tf.stack_loss: 109.0104
# Epoch 72/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7544 - tf.stack_loss: 109.0104
# Epoch 73/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7565 - tf.stack_loss: 109.0104
# Epoch 74/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7586 - tf.stack_loss: 109.0104
# Epoch 75/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7607 - tf.stack_loss: 109.0104
# Epoch 76/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7628 - tf.stack_loss: 109.0104
# Epoch 77/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7649 - tf.stack_loss: 109.0104
# Epoch 78/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7670 - tf.stack_loss: 109.0104
# Epoch 79/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7690 - tf.stack_loss: 109.0104
# Epoch 80/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7711 - tf.stack_loss: 109.0104
# Epoch 81/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7731 - tf.stack_loss: 109.0104
# Epoch 82/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7752 - tf.stack_loss: 109.0104
# Epoch 83/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7772 - tf.stack_loss: 109.0104
# Epoch 84/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7792 - tf.stack_loss: 109.0104
# Epoch 85/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7812 - tf.stack_loss: 109.0104
# Epoch 86/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7832 - tf.stack_loss: 109.0104
# Epoch 87/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7852 - tf.stack_loss: 109.0104
# Epoch 88/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7871 - tf.stack_loss: 109.0104
# Epoch 89/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7891 - tf.stack_loss: 109.0104
# Epoch 90/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7910 - tf.stack_loss: 109.0104
# Epoch 91/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7930 - tf.stack_loss: 109.0104
# Epoch 92/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7949 - tf.stack_loss: 109.0104
# Epoch 93/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7968 - tf.stack_loss: 109.0104
# Epoch 94/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.7987 - tf.stack_loss: 109.0104
# Epoch 95/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8006 - tf.stack_loss: 109.0104
# Epoch 96/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8024 - tf.stack_loss: 109.0104
# Epoch 97/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8043 - tf.stack_loss: 109.0104
# Epoch 98/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8061 - tf.stack_loss: 109.0104
# Epoch 99/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8080 - tf.stack_loss: 109.0104
# Epoch 100/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8098 - tf.stack_loss: 109.0104
# Epoch 101/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8116 - tf.stack_loss: 109.0104
# Epoch 102/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8134 - tf.stack_loss: 109.0104
# Epoch 103/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8152 - tf.stack_loss: 109.0104
# Epoch 104/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8169 - tf.stack_loss: 109.0104
# Epoch 105/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8187 - tf.stack_loss: 109.0104
# Epoch 106/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8204 - tf.stack_loss: 109.0104
# Epoch 107/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8222 - tf.stack_loss: 109.0104
# Epoch 108/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8239 - tf.stack_loss: 109.0104
# Epoch 109/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8256 - tf.stack_loss: 109.0104
# Epoch 110/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8273 - tf.stack_loss: 109.0104
# Epoch 111/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8290 - tf.stack_loss: 109.0104
# Epoch 112/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8306 - tf.stack_loss: 109.0104
# Epoch 113/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8323 - tf.stack_loss: 109.0104
# Epoch 114/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8339 - tf.stack_loss: 109.0104
# Epoch 115/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8355 - tf.stack_loss: 109.0104
# Epoch 116/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8371 - tf.stack_loss: 109.0104
# Epoch 117/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8387 - tf.stack_loss: 109.0104
# Epoch 118/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8403 - tf.stack_loss: 109.0104
# Epoch 119/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8419 - tf.stack_loss: 109.0104
# Epoch 120/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8435 - tf.stack_loss: 109.0104
# Epoch 121/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8450 - tf.stack_loss: 109.0104
# Epoch 122/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8465 - tf.stack_loss: 109.0104
# Epoch 123/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8481 - tf.stack_loss: 109.0104
# Epoch 124/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8496 - tf.stack_loss: 109.0104
# Epoch 125/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8511 - tf.stack_loss: 109.0104
# Epoch 126/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8525 - tf.stack_loss: 109.0104
# Epoch 127/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8540 - tf.stack_loss: 109.0104
# Epoch 128/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8555 - tf.stack_loss: 109.0104
# Epoch 129/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8569 - tf.stack_loss: 109.0104
# Epoch 130/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8583 - tf.stack_loss: 109.0104
# Epoch 131/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8597 - tf.stack_loss: 109.0104
# Epoch 132/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8611 - tf.stack_loss: 109.0104
# Epoch 133/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8625 - tf.stack_loss: 109.0104
# Epoch 134/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8639 - tf.stack_loss: 109.0104
# Epoch 135/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8653 - tf.stack_loss: 109.0104
# Epoch 136/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8666 - tf.stack_loss: 109.0104
# Epoch 137/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8680 - tf.stack_loss: 109.0104
# Epoch 138/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8693 - tf.stack_loss: 109.0104
# Epoch 139/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8706 - tf.stack_loss: 109.0104
# Epoch 140/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8719 - tf.stack_loss: 109.0104
# Epoch 141/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8732 - tf.stack_loss: 109.0104
# Epoch 142/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8745 - tf.stack_loss: 109.0104
# Epoch 143/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8758 - tf.stack_loss: 109.0104
# Epoch 144/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8770 - tf.stack_loss: 109.0104
# Epoch 145/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8783 - tf.stack_loss: 109.0104
# Epoch 146/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8795 - tf.stack_loss: 109.0104
# Epoch 147/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8807 - tf.stack_loss: 109.0104
# Epoch 148/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8819 - tf.stack_loss: 109.0104
# Epoch 149/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8831 - tf.stack_loss: 109.0104
# Epoch 150/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8843 - tf.stack_loss: 109.0104
# Epoch 151/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8855 - tf.stack_loss: 109.0104
# Epoch 152/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8867 - tf.stack_loss: 109.0104
# Epoch 153/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8878 - tf.stack_loss: 109.0104
# Epoch 154/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8890 - tf.stack_loss: 109.0104
# Epoch 155/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8901 - tf.stack_loss: 109.0104
# Epoch 156/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8912 - tf.stack_loss: 109.0104
# Epoch 157/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8923 - tf.stack_loss: 109.0104
# Epoch 158/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8934 - tf.stack_loss: 109.0104
# Epoch 159/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8945 - tf.stack_loss: 109.0104
# Epoch 160/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8956 - tf.stack_loss: 109.0104
# Epoch 161/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8966 - tf.stack_loss: 109.0104
# Epoch 162/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8977 - tf.stack_loss: 109.0104
# Epoch 163/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8987 - tf.stack_loss: 109.0104
# Epoch 164/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.8998 - tf.stack_loss: 109.0104
# Epoch 165/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9008 - tf.stack_loss: 109.0104
# Epoch 166/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9018 - tf.stack_loss: 109.0104
# Epoch 167/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9028 - tf.stack_loss: 109.0104
# Epoch 168/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9038 - tf.stack_loss: 109.0104
# Epoch 169/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9048 - tf.stack_loss: 109.0104
# Epoch 170/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9057 - tf.stack_loss: 109.0104
# Epoch 171/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9067 - tf.stack_loss: 109.0104
# Epoch 172/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9076 - tf.stack_loss: 109.0104
# Epoch 173/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9086 - tf.stack_loss: 109.0104
# Epoch 174/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9095 - tf.stack_loss: 109.0104
# Epoch 175/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9104 - tf.stack_loss: 109.0104
# Epoch 176/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9113 - tf.stack_loss: 109.0104
# Epoch 177/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9122 - tf.stack_loss: 109.0104
# Epoch 178/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9131 - tf.stack_loss: 109.0104
# Epoch 179/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9140 - tf.stack_loss: 109.0104
# Epoch 180/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9149 - tf.stack_loss: 109.0104
# Epoch 181/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9157 - tf.stack_loss: 109.0104
# Epoch 182/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9166 - tf.stack_loss: 109.0104
# Epoch 183/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9174 - tf.stack_loss: 109.0104
# Epoch 184/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9183 - tf.stack_loss: 109.0104
# Epoch 185/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9191 - tf.stack_loss: 109.0104
# Epoch 186/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9199 - tf.stack_loss: 109.0104
# Epoch 187/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9207 - tf.stack_loss: 109.0104
# Epoch 188/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9215 - tf.stack_loss: 109.0104
# Epoch 189/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9223 - tf.stack_loss: 109.0104
# Epoch 190/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9231 - tf.stack_loss: 109.0104
# Epoch 191/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9239 - tf.stack_loss: 109.0104
# Epoch 192/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9246 - tf.stack_loss: 109.0104
# Epoch 193/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9254 - tf.stack_loss: 109.0104
# Epoch 194/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9261 - tf.stack_loss: 109.0104
# Epoch 195/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9269 - tf.stack_loss: 109.0104
# Epoch 196/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9276 - tf.stack_loss: 109.0104
# Epoch 197/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9284 - tf.stack_loss: 109.0104
# Epoch 198/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9291 - tf.stack_loss: 109.0104
# Epoch 199/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9298 - tf.stack_loss: 109.0104
# Epoch 200/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9305 - tf.stack_loss: 109.0104
# Epoch 201/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9312 - tf.stack_loss: 109.0104
# Epoch 202/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9319 - tf.stack_loss: 109.0104
# Epoch 203/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9325 - tf.stack_loss: 109.0104
# Epoch 204/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9332 - tf.stack_loss: 109.0104
# Epoch 205/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9339 - tf.stack_loss: 109.0104
# Epoch 206/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9346 - tf.stack_loss: 109.0104
# Epoch 207/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9352 - tf.stack_loss: 109.0104
# Epoch 208/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9358 - tf.stack_loss: 109.0104
# Epoch 209/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9365 - tf.stack_loss: 109.0104
# Epoch 210/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9371 - tf.stack_loss: 109.0104
# Epoch 211/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9377 - tf.stack_loss: 109.0104
# Epoch 212/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9384 - tf.stack_loss: 109.0104
# Epoch 213/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9390 - tf.stack_loss: 109.0104
# Epoch 214/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9396 - tf.stack_loss: 109.0104
# Epoch 215/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9402 - tf.stack_loss: 109.0104
# Epoch 216/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9408 - tf.stack_loss: 109.0104
# Epoch 217/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9413 - tf.stack_loss: 109.0104
# Epoch 218/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9419 - tf.stack_loss: 109.0104
# Epoch 219/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9425 - tf.stack_loss: 109.0104
# Epoch 220/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9431 - tf.stack_loss: 109.0104
# Epoch 221/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9436 - tf.stack_loss: 109.0104
# Epoch 222/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9442 - tf.stack_loss: 109.0104
# Epoch 223/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9447 - tf.stack_loss: 109.0104
# Epoch 224/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9453 - tf.stack_loss: 109.0104
# Epoch 225/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9458 - tf.stack_loss: 109.0104
# Epoch 226/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9463 - tf.stack_loss: 109.0104
# Epoch 227/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9468 - tf.stack_loss: 109.0104
# Epoch 228/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9474 - tf.stack_loss: 109.0104
# Epoch 229/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9479 - tf.stack_loss: 109.0104
# Epoch 230/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9484 - tf.stack_loss: 109.0104
# Epoch 231/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9489 - tf.stack_loss: 109.0104
# Epoch 232/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9494 - tf.stack_loss: 109.0104
# Epoch 233/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9499 - tf.stack_loss: 109.0104
# Epoch 234/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9503 - tf.stack_loss: 109.0104
# Epoch 235/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9508 - tf.stack_loss: 109.0104
# Epoch 236/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9513 - tf.stack_loss: 109.0104
# Epoch 237/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9518 - tf.stack_loss: 109.0104
# Epoch 238/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9522 - tf.stack_loss: 109.0104
# Epoch 239/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9527 - tf.stack_loss: 109.0104
# Epoch 240/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9531 - tf.stack_loss: 109.0104
# Epoch 241/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9536 - tf.stack_loss: 109.0104
# Epoch 242/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9540 - tf.stack_loss: 109.0104
# Epoch 243/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9544 - tf.stack_loss: 109.0104
# Epoch 244/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9549 - tf.stack_loss: 109.0104
# Epoch 245/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9553 - tf.stack_loss: 109.0104
# Epoch 246/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9557 - tf.stack_loss: 109.0104
# Epoch 247/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9561 - tf.stack_loss: 109.0104
# Epoch 248/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9566 - tf.stack_loss: 109.0104
# Epoch 249/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9570 - tf.stack_loss: 109.0104
# Epoch 250/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9574 - tf.stack_loss: 109.0104
# Epoch 251/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9578 - tf.stack_loss: 109.0104
# Epoch 252/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9581 - tf.stack_loss: 109.0104
# Epoch 253/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9585 - tf.stack_loss: 109.0104
# Epoch 254/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9589 - tf.stack_loss: 109.0104
# Epoch 255/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9593 - tf.stack_loss: 109.0104
# Epoch 256/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9597 - tf.stack_loss: 109.0104
# Epoch 257/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9600 - tf.stack_loss: 109.0104
# Epoch 258/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9604 - tf.stack_loss: 109.0104
# Epoch 259/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9608 - tf.stack_loss: 109.0104
# Epoch 260/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9611 - tf.stack_loss: 109.0104
# Epoch 261/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9615 - tf.stack_loss: 109.0104
# Epoch 262/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9618 - tf.stack_loss: 109.0104
# Epoch 263/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9622 - tf.stack_loss: 109.0104
# Epoch 264/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9625 - tf.stack_loss: 109.0104
# Epoch 265/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9629 - tf.stack_loss: 109.0104
# Epoch 266/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9632 - tf.stack_loss: 109.0104
# Epoch 267/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9635 - tf.stack_loss: 109.0104
# Epoch 268/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9638 - tf.stack_loss: 109.0104
# Epoch 269/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9642 - tf.stack_loss: 109.0104
# Epoch 270/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9645 - tf.stack_loss: 109.0104
# Epoch 271/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9648 - tf.stack_loss: 109.0104
# Epoch 272/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9651 - tf.stack_loss: 109.0104
# Epoch 273/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9654 - tf.stack_loss: 109.0104
# Epoch 274/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9657 - tf.stack_loss: 109.0104
# Epoch 275/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9660 - tf.stack_loss: 109.0104
# Epoch 276/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9663 - tf.stack_loss: 109.0104
# Epoch 277/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9666 - tf.stack_loss: 109.0104
# Epoch 278/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9669 - tf.stack_loss: 109.0104
# Epoch 279/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9672 - tf.stack_loss: 109.0104
# Epoch 280/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9675 - tf.stack_loss: 109.0104
# Epoch 281/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9678 - tf.stack_loss: 109.0104
# Epoch 282/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9681 - tf.stack_loss: 109.0104
# Epoch 283/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9683 - tf.stack_loss: 109.0104
# Epoch 284/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9686 - tf.stack_loss: 109.0104
# Epoch 285/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9689 - tf.stack_loss: 109.0104
# Epoch 286/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9691 - tf.stack_loss: 109.0104
# Epoch 287/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9694 - tf.stack_loss: 109.0104
# Epoch 288/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9697 - tf.stack_loss: 109.0104
# Epoch 289/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9699 - tf.stack_loss: 109.0104
# Epoch 290/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9702 - tf.stack_loss: 109.0104
# Epoch 291/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9704 - tf.stack_loss: 109.0104
# Epoch 292/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9707 - tf.stack_loss: 109.0104
# Epoch 293/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9709 - tf.stack_loss: 109.0104
# Epoch 294/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9712 - tf.stack_loss: 109.0104
# Epoch 295/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9714 - tf.stack_loss: 109.0104
# Epoch 296/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9717 - tf.stack_loss: 109.0104
# Epoch 297/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9719 - tf.stack_loss: 109.0104
# Epoch 298/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9721 - tf.stack_loss: 109.0104
# Epoch 299/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9724 - tf.stack_loss: 109.0104
# Epoch 300/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.1659 - tf.nn.softmax_loss: 0.0193 - Nuclear_Abundances_loss: 0.0567 - tf.math.reduce_sum_loss: -0.9726 - tf.stack_loss: 109.0104
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 18
#       8 currentModelTrainingHistory=unmixingModel.fit(x=preprocessedSpectra,
#       9                                                         y=[regularElementalAbundances,
#      10                                                            nuclearElementalAbundances,
#    (...)
#      13                                                         batch_size=batchSize,
#      14                                                         epochs=noOfEpochs)
#      17 #save the training history of the current model
# ---> 18 modelTrainingHistories.append(currentModelTrainingHistory)
#      22 #set the address where the untrained model will be saved
#      23 trainedModelWeightsAddress="D:/Non-academic/GSOC23/trained_Regularized_Constrainted_Dual_Unmixing_Model_With_PReLU_Weights_and_Linear_Decoder.h5"
#
# NameError: name 'modelTrainingHistories' is not defined

# %%
#iterate through all the elements
for i in range(len(allElementNames)):

    #get the mean spectrum for the current element
    currentElementSpectrum=unmixingModel.get_layer(allElementNames[i]+"_Spectra").get_weights()[0][0]

    #save the spectrum
    learntElementalSpectra[:,i]=currentElementSpectrum

# %%
#create a figure 
figure,axes=plt.subplots(nrows=2,
                         ncols=5,
                         figsize=(5*5,5*2),
                         dpi=100,
                         sharex=True,
                         sharey=True)


#iterate through all the elements
for i in range(len(allElementNames)):

    #get the name of the current element
    currentElementName=allElementNames[i]

    #get the mean spectrum for the current element
    currentElementSpectrum=learntElementalSpectra[:,i]

    #plot the spectrum
    axes[i//5,i%5].bar(relaventEnergyBands,
                       currentElementSpectrum/np.linalg.norm(currentElementSpectrum),
                       lw=10,
                       width=10)

    #add the title
    axes[i//5,i%5].set_title(currentElementName,
                             fontsize=baseFontSize*1.2)

    #set the margin
    axes[i//5,i%5].margins(0.01)

    #add xticks and label
    if i//5==1:
        axes[i//5,i%5].set_xticks(np.arange(np.amin(relaventEnergyBands),
                                            np.amax(relaventEnergyBands)+np.ptp(relaventEnergyBands)/noOfXticks,
                                            np.ptp(relaventEnergyBands)/noOfXticks),
                                  labels=np.round(np.arange(np.amin(relaventEnergyBands),
                                                            np.amax(relaventEnergyBands)+np.ptp(relaventEnergyBands)/noOfXticks,
                                                            np.ptp(relaventEnergyBands)/noOfXticks),
                                                  0).astype('int'),
                                  fontsize=baseFontSize*1.1)
        axes[i//5,i%5].set_xlabel("KeV",fontsize=baseFontSize*1.2)

    #add yticks and label
    if i%5==0:
        axes[i//5,i%5].set_ylabel("log(Counts/min) ratioed",fontsize=baseFontSize*1.2)

    axes[i//5,i%5].set_yticks(np.arange(0,
                                np.amax(currentElementSpectrum)+np.ptp(currentElementSpectrum)/noOfYticks,
                                np.ptp(currentElementSpectrum)/noOfYticks),
                      labels=np.round(np.arange(0,
                                                np.amax(currentElementSpectrum)+np.ptp(currentElementSpectrum)/noOfYticks,
                                                np.ptp(currentElementSpectrum)/noOfYticks),
                                      2),
                      fontsize=baseFontSize*1.1)
#add a title
figure.suptitle(f"Element-wise Learnt spectra",
                fontsize=baseFontSize*1.5)
# Out:
# Text(0.5, 0.98, 'Element-wise Learnt spectra')

# %%
#import uniform_filter from scipy
from scipy.ndimage import uniform_filter

# %%
#create an array to hold the smoothened element-wise spectra
smoothenedElementWiseSpectra=np.zeros_like(learntElementalSpectra)

#create a figure 
figure,axes=plt.subplots(nrows=2,
                         ncols=5,
                         figsize=(5*5,5*2),
                         dpi=100,
                         sharex=True,
                         sharey=True)

#iterate through the element-wise spectra and smoothen them
for i in range(len(allElementNames)):
    
    #get the name of the current element
    currentElementName=allElementNames[i]
    
    #get the mean spectrum for the current element
    currentElementSpectrum=learntElementalSpectra[:,i]
    
    #normalize and smoothen the spectra
    currentElementSpectrum=currentElementSpectrum/np.linalg.norm(currentElementSpectrum)
    
    #smoothen the spectrum
    currentElementSpectrum=uniform_filter(currentElementSpectrum,
                                          size=9)
    currentElementSpectrum=currentElementSpectrum/np.linalg.norm(currentElementSpectrum)
    
    #plot the spectrum
    axes[i//5,i%5].plot(relaventEnergyBands,
                        currentElementSpectrum,
                        lw=3)

    #add the title
    axes[i//5,i%5].set_title(currentElementName,
                             fontsize=baseFontSize*1.2)

    #set the margin
    axes[i//5,i%5].margins(0.01)

    #add xticks and label
    if i//5==1:
        axes[i//5,i%5].set_xticks(np.arange(np.amin(relaventEnergyBands),
                                            np.amax(relaventEnergyBands)+np.ptp(relaventEnergyBands)/noOfXticks,
                                            np.ptp(relaventEnergyBands)/noOfXticks),
                                  labels=np.round(np.arange(np.amin(relaventEnergyBands),
                                                            np.amax(relaventEnergyBands)+np.ptp(relaventEnergyBands)/noOfXticks,
                                                            np.ptp(relaventEnergyBands)/noOfXticks),
                                                  0).astype('int'),
                                  fontsize=baseFontSize*1.1)
        axes[i//5,i%5].set_xlabel("KeV",fontsize=baseFontSize*1.2)

    #add yticks and label
    if i%5==0:
        axes[i//5,i%5].set_ylabel("log(Counts/min) ratioed",fontsize=baseFontSize*1.2)

    axes[i//5,i%5].set_yticks(np.arange(0,
                                np.amax(currentElementSpectrum)+np.ptp(currentElementSpectrum)/noOfYticks,
                                np.ptp(currentElementSpectrum)/noOfYticks),
                      labels=np.round(np.arange(0,
                                                np.amax(currentElementSpectrum)+np.ptp(currentElementSpectrum)/noOfYticks,
                                                np.ptp(currentElementSpectrum)/noOfYticks),
                                      2),
                      fontsize=baseFontSize*1.1)
#add a title
figure.suptitle(f"Smoothened Element-wise Learnt spectra",
                fontsize=baseFontSize*1.5)
# Out:
# Text(0.5, 0.98, 'Smoothened Element-wise Learnt spectra')
